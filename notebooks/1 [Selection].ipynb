# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data_path = '..\data\external\dados_cepagri_2017_2018.csv'
df_data = pd.read_csv(data_path)
df_data.head()
# Out:
#    Unnamed: 0  Cod   Ano  Dia Juliano  Hora - minuto  \
# 0     1035001  111  2017            1             10
# 1     1035002  111  2017            1             20
# 2     1035003  111  2017            1             30
# 3     1035004  111  2017            1             40
# 4     1035005  111  2017            1             50
#
#    Veloc. Instantânea do Vento a 5 metros (m/s)  \
# 0                                         0.339
# 1                                         0.774
# 2                                         0.659
# 3                                         0.983
# 4                                         0.045
#
#    Veloc. Instantânea do Vento a 2 metros (m/s)  \
# 0                                         0.103
# 1                                         0.430
# 2                                         0.568
# 3                                         0.668
# 4                                         0.319
#
#    Direção do Vento no instante da aquisição (°)  \
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103025 entries, 0 to 103024
# Data columns (total 19 columns):
# Unnamed: 0                                                           103025 non-null int64
# Cod                                                                  103025 non-null int64
# Ano                                                                  103025 non-null int64
# Dia Juliano                                                          103025 non-null int64
# Hora - minuto                                                        103025 non-null int64
# Veloc. Instantânea do Vento a 5 metros (m/s)                         103025 non-null float64
# Veloc. Instantânea do Vento a 2 metros (m/s)                         103025 non-null float64
# Direção do Vento no instante da aquisição (°)                        103025 non-null float64
# Radiação Incidente total de 10 leituras (KW/m2)                      103025 non-null float64
# ...

# %%
df_util = df_data[['Ano','Dia Juliano','Hora - minuto','Temperatura do Ar Média (°C)','Umidade relativa Média (%)']]
df_util.sample(5)
# Out:
#         Ano  Dia Juliano  Hora - minuto  Temperatura do Ar Média (°C)  \
# 96159  2018          318            750                         27.09
# 80695  2018          207            250                         15.60
# 19726  2017          147           2310                         19.64
# 31123  2017          227           2040                         16.50
# 21561  2017          161           1100                         15.51
#
#        Umidade relativa Média (%)
# 96159                       67.40
# 80695                       78.90
# 19726                       78.20
# 31123                       72.70
# 21561                       57.07

# %%
df_util.corr(method='spearman')
# Out:
#                                    Ano  Dia Juliano  Hora - minuto  \
# Ano                           1.000000    -0.016485      -0.000933
# Dia Juliano                  -0.016485     1.000000      -0.000637
# Hora - minuto                -0.000933    -0.000637       1.000000
# Temperatura do Ar Média (°C)  0.038818    -0.047647       0.310436
# Umidade relativa Média (%)   -0.003485    -0.112643      -0.294809
#
#                               Temperatura do Ar Média (°C)  \
# Ano                                               0.038818
# Dia Juliano                                      -0.047647
# Hora - minuto                                     0.310436
# Temperatura do Ar Média (°C)                      1.000000
# Umidade relativa Média (%)                       -0.568083
#
#                               Umidade relativa Média (%)
# Ano                                            -0.003485
# Dia Juliano                                    -0.112643
# ...

# %%
df_util.columns = ['Ano','Dia Juliano','Hora - minuto','Temperatura','Umidade']
df_util = df_util[df_util['Temperatura']>0]
df_util.hist()
# Out:
# <img src="data:image/png;base64,..." width="859.5555555555555">
# C:\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
df_util['Temperatura'].plot()
# Out:
# <img src="data:image/png;base64,..." width="876.4444444444445">

# %%
df_util['Umidade'].plot()
# Out:
# <img src="data:image/png;base64,..." width="941.3333333333334">

# %%
df_util.to_csv('..\data\interim\dataset_2017_2018[Selection].csv',index_label='ID')
