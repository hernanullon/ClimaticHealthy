# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data_path = '..\data\external\cetesb_janeiro_2020.csv'
df_data1 = pd.read_csv(data_path,sep=';')
data_path = '..\data\external\cetesb_fevereiro_2020.csv'
df_data2 = pd.read_csv(data_path,sep=';')
data_path = '..\data\external\cetesb_marco_2020.csv'
df_data3 = pd.read_csv(data_path,sep=';')
data_path = '..\data\external\cetesb_abril_2020.csv'
df_data4 = pd.read_csv(data_path,sep=';')
data_path = '..\data\external\cetesb_maio_2020.csv'
df_data5 = pd.read_csv(data_path,sep=';')
df_data2
# Out:
#        ts     T   U   T.1  U.1   T.2  U.2   T.3  U.3   T.4  ...  T.23  U.23  \
# 0   00:00  22.0  88  23.0   89  21.4   95  20.9   86  21.8  ...  21.6    96
# 1   01:00  22.2  89  22.8   89  21.4   96  20.8   85  21.8  ...  21.8    96
# 2   02:00  22.4  90  22.7   90  21.3   96  21.0   83  21.9  ...  21.7    96
# 3   03:00  22.4  91  22.3   90  21.2   96  21.0   84  21.9  ...  21.4    96
# 4   04:00  22.4  92  22.1   90  21.2   96  20.7   85  21.7  ...  21.0    96
# 5   05:00  22.2  92  21.9   92  21.1   96  20.7   87  21.9  ...  20.8    96
# 6   06:00  22.3  92  21.8   92  20.9   96  20.6   88  21.9  ...  20.9    96
# 7   07:00  22.5  92  21.9   92  20.8   96  20.8   89  21.9  ...  21.0    96
# 8   08:00  22.9  90  22.7   93  21.6   97  21.0   90  22.3  ...  22.3    96
# 9   09:00  24.0  85  23.7   89  22.2   97  21.5   91  22.7  ...  23.3    93
# 10  10:00  25.4  78  25.4   81  23.3   95  22.8   90  23.7  ...  25.2    77
# ...

# %%
T = []
U = []
for i in range(1,df_data1.shape[1],2):
    T.append(df_data1.iloc[:,i].values)
    U.append(df_data1.iloc[:,i+1].values)

new_index1 = pd.date_range('2020-01-01', '2020-02-01', freq='H')
new_index1 = new_index1[:-1]
d = {
     'ts': new_index1, 
     'Temperatura': np.array(T).ravel(),
     'Umidade': np.array(U).ravel(),
    }
df_data_janeiro = pd.DataFrame(data=d)
df_data_janeiro.isna().sum()
# Out:
# ts             0
# Temperatura    1
# Umidade        1
# dtype: int64

# %%
T = []
U = []
for i in range(1,df_data2.shape[1],2):
    T.append(df_data2.iloc[:,i].values)
    U.append(df_data2.iloc[:,i+1].values)

new_index2 = pd.date_range('2020-02-01', '2020-03-01', freq='H')
new_index2 = new_index2[:-1]
d = {
     'ts': new_index2, 
     'Temperatura': np.array(T).ravel(),
     'Umidade': np.array(U).ravel(),
    }
df_data_fevereiro = pd.DataFrame(data=d)
df_data_fevereiro.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-44bafdbdf915> in <module>
#      12      'Umidade': np.array(U).ravel(),
#      13     }
# ---> 14 df_data_fevereiro = pd.DataFrame(data=d)
#      15 df_data_fevereiro.isna().sum()
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# ...

# %%
T = []
U = []
for i in range(1,df_data3.shape[1],2):
    T.append(df_data3.iloc[:,i].values)
    U.append(df_data3.iloc[:,i+1].values)

new_index3 = pd.date_range('2020-03-01', '2020-04-01', freq='H')
new_index3 = new_index3[:-1]
d = {
     'ts': new_index3, 
     'Temperatura': np.array(T).ravel(),
     'Umidade': np.array(U).ravel(),
    }
df_data_marco = pd.DataFrame(data=d)
df_data_marco.isna().sum()
# Out:
# ts             0
# Temperatura    3
# Umidade        3
# dtype: int64

# %%
T = []
U = []
for i in range(1,df_data4.shape[1],2):
    T.append(df_data4.iloc[:,i].values)
    U.append(df_data4.iloc[:,i+1].values)

new_index4 = pd.date_range('2020-04-01', '2020-05-01', freq='H')
new_index4 = new_index4[:-1]
d = {
     'ts': new_index4, 
     'Temperatura': np.array(T).ravel(),
     'Umidade': np.array(U).ravel(),
    }
df_data_abril = pd.DataFrame(data=d)
df_data_abril.isna().sum()
# Out:
# ts              0
# Temperatura    29
# Umidade        29
# dtype: int64

# %%
T = []
U = []
for i in range(1,df_data5.shape[1],2):
    T.append(df_data5.iloc[:,i].values)
    U.append(df_data5.iloc[:,i+1].values)

new_index5 = pd.date_range('2020-05-01', '2020-06-01', freq='H')
new_index5 = new_index5[:-1]
d = {
     'ts': new_index5, 
     'Temperatura': np.array(T).ravel(),
     'Umidade': np.array(U).ravel(),
    }
df_data_maio = pd.DataFrame(data=d)
df_data_maio.isna().sum()
# Out:
# ts              0
# Temperatura    10
# Umidade        10
# dtype: int64

# %%
df_data_janeiro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 3 columns):
# ts             744 non-null datetime64[ns]
# Temperatura    742 non-null float64
# Umidade        742 non-null float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 17.6 KB

# %%
df_data_2020 = pd.concat([df_data_janeiro,df_data_fevereiro,df_data_marco,df_data_abril,df_data_maio])
df_data_2020['ts'] = pd.to_datetime(df_data_2020['ts'])
df_data_2020 = df_data_2020.set_index('ts')
df_data_2020.isna().sum()
# Out:
# Temperatura    45
# Umidade        45
# dtype: int64

# %%
df_data_2020['Umidade'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
interpolated = df_data_2020.interpolate(method='linear')

# %%
interpolated['Temperatura'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
interpolated.describe()
# Out:
#        Temperatura      Umidade
# count  3648.000000  3648.000000
# mean     22.347464    65.680373
# std       4.925532    18.552077
# min       7.400000    22.000000
# 25%      19.100000    51.500000
# 50%      22.200000    70.000000
# 75%      25.800000    80.000000
# max      36.000000    98.000000

# %%
interpolated.to_csv('..\data\external\dataset_cetesb_2020.csv')
